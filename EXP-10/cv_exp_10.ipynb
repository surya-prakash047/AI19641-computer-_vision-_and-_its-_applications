# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchvision.utils import make_grid

# Set random seed for reproducibility
torch.manual_seed(42)

# Hyperparameters
latent_dim = 100
hidden_dim = 256
image_dim = 784  # 28x28 images
num_epochs = 20
batch_size = 64
lr = 0.0002
beta1 = 0.5

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])  # Normalize to [-1, 1]
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, image_dim),
            nn.Tanh()  # Output range [-1, 1]
        )

    def forward(self, z):
        img = self.model(z)
        return img.view(img.size(0), 1, 28, 28)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(image_dim, hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(0.2),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()  # Output probability
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)
        return validity

# Initialize models
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss function
adversarial_loss = nn.BCELoss()

# Optimizers
g_optimizer = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, 0.999))
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

# Training loop
for epoch in range(num_epochs):
    for i, (imgs, _) in enumerate(train_loader):
        batch_size = imgs.size(0)

        # Ground truth labels
        real_label = torch.ones(batch_size, 1).to(device)
        fake_label = torch.zeros(batch_size, 1).to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        d_optimizer.zero_grad()

        # Train with real images
        real_imgs = imgs.to(device)
        real_validity = discriminator(real_imgs)
        d_real_loss = adversarial_loss(real_validity, real_label)

        # Train with fake images
        z = torch.randn(batch_size, latent_dim).to(device)
        fake_imgs = generator(z)
        fake_validity = discriminator(fake_imgs.detach())
        d_fake_loss = adversarial_loss(fake_validity, fake_label)

        # Total discriminator loss
        d_loss = (d_real_loss + d_fake_loss) / 2
        d_loss.backward()
        d_optimizer.step()

        # -----------------
        #  Train Generator
        # -----------------
        g_optimizer.zero_grad()

        # Generate fake images and classify them
        fake_validity = discriminator(fake_imgs)
        g_loss = adversarial_loss(fake_validity, real_label)  # Trick discriminator

        g_loss.backward()
        g_optimizer.step()

        # Print progress
        if i % 200 == 0:
            print(f"[Epoch {epoch}/{num_epochs}] [Batch {i}/{len(train_loader)}] "
                  f"D_loss: {d_loss.item():.4f}, G_loss: {g_loss.item():.4f}")

    # Save generated images every 10 epochs
    if epoch % 10 == 0:
        with torch.no_grad():
            fake_imgs = generator(torch.randn(16, latent_dim).to(device))
            fake_imgs = fake_imgs.cpu()
            grid = make_grid(fake_imgs, nrow=4, normalize=True)

            plt.figure(figsize=(6, 6))
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis('off')
            plt.title(f'Generated Digits at Epoch {epoch}')
            plt.savefig(f'generated_digits_epoch_{epoch}.png')
            plt.close()

# Save final generator model
torch.save(generator.state_dict(), 'generator.pth')

# Generate and display final samples
with torch.no_grad():
    final_samples = generator(torch.randn(16, latent_dim).to(device))
    final_samples = final_samples.cpu()
    grid = make_grid(final_samples, nrow=4, normalize=True)

    plt.figure(figsize=(6, 6))
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.axis('off')
    plt.title('Final Generated Digits')
    plt.savefig('final_generated_digits.png')
    plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.44MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 161kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.30MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.11MB/s]
# [Epoch 0/20] [Batch 0/938] D_loss: 0.7158, G_loss: 0.6988
# [Epoch 0/20] [Batch 200/938] D_loss: 0.5531, G_loss: 0.9756
# [Epoch 0/20] [Batch 400/938] D_loss: 0.2775, G_loss: 2.4450
# [Epoch 0/20] [Batch 600/938] D_loss: 0.3429, G_loss: 1.2322
# [Epoch 0/20] [Batch 800/938] D_loss: 0.2557, G_loss: 2.9511
# [Epoch 1/20] [Batch 0/938] D_loss: 0.2903, G_loss: 1.3386
# [Epoch 1/20] [Batch 200/938] D_loss: 0.3871, G_loss: 5.5600
# [Epoch 1/20] [Batch 400/938] D_loss: 0.3403, G_loss: 4.7022
# [Epoch 1/20] [Batch 600/938] D_loss: 0.1164, G_loss: 3.6703
# [Epoch 1/20] [Batch 800/938] D_loss: 0.1262, G_loss: 3.4077
# [Epoch 2/20] [Batch 0/938] D_loss: 0.1610, G_loss: 4.0698
# [Epoch 2/20] [Batch 200/938] D_loss: 0.1335, G_loss: 2.9015
# [Epoch 2/20] [Batch 400/938] D_loss: 0.0550, G_loss: 6.6555
# [Epoch 2/20] [Batch 600/938] D_loss: 0.1847, G_loss: 2.5013
# [Epoch 2/20] [Batch 800/938] D_loss: 0.1601, G_loss: 4.0004
# [Epoch 3/20] [Batch 0/938] D_loss: 0.0989, G_loss: 5.0322
# [Epoch 3/20] [Batch 200/938] D_loss: 0.3450, G_loss: 7.6222
# [Epoch 3/20] [Batch 400/938] D_loss: 0.1638, G_loss: 2.9868
# [Epoch 3/20] [Batch 600/938] D_loss: 0.2952, G_loss: 6.5532
# [Epoch 3/20] [Batch 800/938] D_loss: 0.1358, G_loss: 3.9675
# [Epoch 4/20] [Batch 0/938] D_loss: 0.1699, G_loss: 6.9122
# [Epoch 4/20] [Batch 200/938] D_loss: 1.0160, G_loss: 0.9823
# [Epoch 4/20] [Batch 400/938] D_loss: 0.1013, G_loss: 3.6144
# [Epoch 4/20] [Batch 600/938] D_loss: 0.0626, G_loss: 7.1848
# [Epoch 4/20] [Batch 800/938] D_loss: 0.0159, G_loss: 5.2463
# [Epoch 5/20] [Batch 0/938] D_loss: 0.0814, G_loss: 4.5052
# [Epoch 5/20] [Batch 200/938] D_loss: 0.0906, G_loss: 3.7092
# [Epoch 5/20] [Batch 400/938] D_loss: 0.0503, G_loss: 5.0329
# [Epoch 5/20] [Batch 600/938] D_loss: 0.6108, G_loss: 2.0515
# [Epoch 5/20] [Batch 800/938] D_loss: 0.0350, G_loss: 2.9808
# [Epoch 6/20] [Batch 0/938] D_loss: 0.0734, G_loss: 2.5307
# [Epoch 6/20] [Batch 200/938] D_loss: 0.9375, G_loss: 5.3936
# [Epoch 6/20] [Batch 400/938] D_loss: 0.2034, G_loss: 2.8960
# [Epoch 6/20] [Batch 600/938] D_loss: 0.1564, G_loss: 2.4776
# [Epoch 6/20] [Batch 800/938] D_loss: 0.2380, G_loss: 4.8753
# [Epoch 7/20] [Batch 0/938] D_loss: 0.1567, G_loss: 2.0991
# [Epoch 7/20] [Batch 200/938] D_loss: 0.1989, G_loss: 3.1051
# [Epoch 7/20] [Batch 400/938] D_loss: 0.2523, G_loss: 1.1309
# [Epoch 7/20] [Batch 600/938] D_loss: 0.1836, G_loss: 2.3485
# [Epoch 7/20] [Batch 800/938] D_loss: 0.2569, G_loss: 1.7105
# [Epoch 8/20] [Batch 0/938] D_loss: 0.4263, G_loss: 7.6739
# [Epoch 8/20] [Batch 200/938] D_loss: 0.1375, G_loss: 2.6752
# [Epoch 8/20] [Batch 400/938] D_loss: 0.2711, G_loss: 2.3546
# [Epoch 8/20] [Batch 600/938] D_loss: 0.1089, G_loss: 2.9968
# [Epoch 8/20] [Batch 800/938] D_loss: 0.2021, G_loss: 1.8191
# [Epoch 9/20] [Batch 0/938] D_loss: 0.1938, G_loss: 3.1487
# [Epoch 9/20] [Batch 200/938] D_loss: 0.2149, G_loss: 2.4336
# [Epoch 9/20] [Batch 400/938] D_loss: 0.4848, G_loss: 4.4544
# [Epoch 9/20] [Batch 600/938] D_loss: 0.2486, G_loss: 2.7535
# [Epoch 9/20] [Batch 800/938] D_loss: 0.2807, G_loss: 1.4768
# [Epoch 10/20] [Batch 0/938] D_loss: 0.2730, G_loss: 2.1049
# [Epoch 10/20] [Batch 200/938] D_loss: 0.2074, G_loss: 2.1908
# [Epoch 10/20] [Batch 400/938] D_loss: 0.1918, G_loss: 2.6537
# [Epoch 10/20] [Batch 600/938] D_loss: 0.3478, G_loss: 4.8673
# [Epoch 10/20] [Batch 800/938] D_loss: 0.1820, G_loss: 2.7488
# [Epoch 11/20] [Batch 0/938] D_loss: 0.2902, G_loss: 3.4843
# [Epoch 11/20] [Batch 200/938] D_loss: 0.1198, G_loss: 4.0780
# [Epoch 11/20] [Batch 400/938] D_loss: 0.1523, G_loss: 3.1110
# [Epoch 11/20] [Batch 600/938] D_loss: 0.1596, G_loss: 1.8850
# [Epoch 11/20] [Batch 800/938] D_loss: 0.2051, G_loss: 3.8633
# [Epoch 12/20] [Batch 0/938] D_loss: 0.4049, G_loss: 3.7349
# [Epoch 12/20] [Batch 200/938] D_loss: 0.2720, G_loss: 3.7681
# [Epoch 12/20] [Batch 400/938] D_loss: 0.1791, G_loss: 2.8204
# [Epoch 12/20] [Batch 600/938] D_loss: 0.3325, G_loss: 2.7580
# [Epoch 12/20] [Batch 800/938] D_loss: 0.4671, G_loss: 4.8675
# [Epoch 13/20] [Batch 0/938] D_loss: 0.3225, G_loss: 4.9177
# [Epoch 13/20] [Batch 200/938] D_loss: 0.2718, G_loss: 1.9592
# [Epoch 13/20] [Batch 400/938] D_loss: 0.4486, G_loss: 1.9326
# [Epoch 13/20] [Batch 600/938] D_loss: 0.1636, G_loss: 3.1890
# [Epoch 13/20] [Batch 800/938] D_loss: 0.4394, G_loss: 2.4249
# [Epoch 14/20] [Batch 0/938] D_loss: 0.2459, G_loss: 1.2013
# [Epoch 14/20] [Batch 200/938] D_loss: 0.2103, G_loss: 4.4256
# [Epoch 14/20] [Batch 400/938] D_loss: 0.0033, G_loss: 13.6077
# [Epoch 14/20] [Batch 600/938] D_loss: 0.1895, G_loss: 6.4828
# [Epoch 14/20] [Batch 800/938] D_loss: 0.2198, G_loss: 2.9226
# [Epoch 15/20] [Batch 0/938] D_loss: 0.4800, G_loss: 4.2781
# [Epoch 15/20] [Batch 200/938] D_loss: 0.3288, G_loss: 1.8859
# [Epoch 15/20] [Batch 400/938] D_loss: 0.5295, G_loss: 0.8037
# [Epoch 15/20] [Batch 600/938] D_loss: 0.2598, G_loss: 2.0535
# [Epoch 15/20] [Batch 800/938] D_loss: 0.3135, G_loss: 1.6982
# [Epoch 16/20] [Batch 0/938] D_loss: 0.4013, G_loss: 2.5000
# [Epoch 16/20] [Batch 200/938] D_loss: 0.3335, G_loss: 2.2403
# [Epoch 16/20] [Batch 400/938] D_loss: 0.3258, G_loss: 2.6896
# [Epoch 16/20] [Batch 600/938] D_loss: 0.2469, G_loss: 2.7781
# [Epoch 16/20] [Batch 800/938] D_loss: 0.3102, G_loss: 2.2634
# [Epoch 17/20] [Batch 0/938] D_loss: 0.3579, G_loss: 1.6473
# [Epoch 17/20] [Batch 200/938] D_loss: 0.4238, G_loss: 1.8304
# [Epoch 17/20] [Batch 400/938] D_loss: 0.3355, G_loss: 1.7211
# [Epoch 17/20] [Batch 600/938] D_loss: 0.2824, G_loss: 1.5230
# [Epoch 17/20] [Batch 800/938] D_loss: 0.3068, G_loss: 1.7493
# [Epoch 18/20] [Batch 0/938] D_loss: 0.3341, G_loss: 2.2503
# [Epoch 18/20] [Batch 200/938] D_loss: 0.3220, G_loss: 1.4427
# [Epoch 18/20] [Batch 400/938] D_loss: 0.3575, G_loss: 2.6699
# [Epoch 18/20] [Batch 600/938] D_loss: 0.2907, G_loss: 1.6321
# [Epoch 18/20] [Batch 800/938] D_loss: 0.3716, G_loss: 2.5735
# [Epoch 19/20] [Batch 0/938] D_loss: 0.9094, G_loss: 2.9775
# [Epoch 19/20] [Batch 200/938] D_loss: 0.4016, G_loss: 1.5394
# [Epoch 19/20] [Batch 400/938] D_loss: 0.7443, G_loss: 0.7907
# [Epoch 19/20] [Batch 600/938] D_loss: 0.5443, G_loss: 2.3084
# [Epoch 19/20] [Batch 800/938] D_loss: 0.3255, G_loss: 2.0283
